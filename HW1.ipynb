# %%
# !pip install pandas pyarrow
import numpy as np
import pandas as pd
from google.colab import files
files=files.upload()
# Out:
# ...
#      <input type="file" id="files-a39606ae-1f6c-46a6-8690-6d66fd527289" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a39606ae-1f6c-46a6-8690-6d66fd527289">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# (b)

# %%
Auto=pd.read_csv('/content/Auto.csv')
Auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].max())
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          5140.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].min())
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# dtype: float64

# %% [markdown]
# (c)

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].mean())
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# dtype: float64

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].std())
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# dtype: float64

# %% [markdown]
# (d)

# %%
Auto=Auto.drop(labels=range(10, 86), axis=0)
Auto

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].max())
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          4997.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].min())
# Out:
# mpg               11.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1649.0
# acceleration       8.5
# year              70.0
# dtype: float64

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].mean())
# Out:
# mpg               24.407595
# cylinders          5.373418
# displacement     187.512658
# horsepower       100.848101
# weight          2936.534810
# acceleration      15.717405
# year              77.136076
# dtype: float64

# %%
print(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']].std())
# Out:
# mpg               7.863285
# cylinders         1.654179
# displacement    100.114616
# horsepower       35.954147
# weight          811.874450
# acceleration      2.713876
# year              3.123464
# dtype: float64

# %% [markdown]
# (e)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(Auto[['mpg','cylinders','displacement','horsepower','weight','acceleration','year']], diag_kind='hist')

plt.show()

# %% [markdown]
# mpg: displacement, horsepower, weight are inversely proportional
# , accel has a weak negative correlation

# %% [markdown]
# (f)

# %% [markdown]
# displacement, horsepower, weight might be useful in predicting mpg
